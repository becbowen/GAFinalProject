# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
predictor = pd.read_excel("EnsAmFindingsCcasSsffs.xlsx", index_col = [0] )
predictor.head()
# Out:
#                    Site  Year  ENCount  ScramCount  Column #  TotalFindings  \
# 0  ARKANSAS NUCLEAR ONE  2006        2           0         1             11
# 1  ARKANSAS NUCLEAR ONE  2007        2           1         1             26
# 2  ARKANSAS NUCLEAR ONE  2008        5           2         1             21
# 3  ARKANSAS NUCLEAR ONE  2009       12           5         2             21
# 4  ARKANSAS NUCLEAR ONE  2010        4           2         1             24
#
#    HU  PIR  SSFF
# 0   6    2     0
# 1  15    6     0
# 2  14    2     0
# 3  15    7     1
# 4  14    5     0

# %%
AMNextYear = predictor[["Site","Year","Column #"]]
AMNextYear.head()
# Out:
#                    Site  Year  Column #
# 0  ARKANSAS NUCLEAR ONE  2006         1
# 1  ARKANSAS NUCLEAR ONE  2007         1
# 2  ARKANSAS NUCLEAR ONE  2008         1
# 3  ARKANSAS NUCLEAR ONE  2009         2
# 4  ARKANSAS NUCLEAR ONE  2010         1

# %%
AMNextYear = AMNextYear[AMNextYear["Year"] != 2006]
AMNextYear.head()
# Out:
#                    Site  Year  Column #
# 1  ARKANSAS NUCLEAR ONE  2007         1
# 2  ARKANSAS NUCLEAR ONE  2008         1
# 3  ARKANSAS NUCLEAR ONE  2009         2
# 4  ARKANSAS NUCLEAR ONE  2010         1
# 5  ARKANSAS NUCLEAR ONE  2011         1

# %%
AMNextYear["NextYearColumn"] = AMNextYear["Column #"]

# %%
AMNextYear = AMNextYear.reset_index()
AMNextYear.tail()
# Out:
#      index        Site  Year  Column #  NextYearColumn
# 813    878  WOLF CREEK  2015         1               1
# 814    879  WOLF CREEK  2016         1               1
# 815    880  WOLF CREEK  2017         2               2
# 816    881  WOLF CREEK  2018         2               2
# 817    882  WOLF CREEK  2019         1               1

# %%
AMNextYear = AMNextYear.drop(["index"], axis = 1)
AMNextYear.tail()
# Out:
#            Site  Year  Column #  NextYearColumn
# 813  WOLF CREEK  2015         1               1
# 814  WOLF CREEK  2016         1               1
# 815  WOLF CREEK  2017         2               2
# 816  WOLF CREEK  2018         2               2
# 817  WOLF CREEK  2019         1               1

# %%
predictor = predictor[predictor["Year"] != 2019]
predictor.tail()
# Out:
#            Site  Year  ENCount  ScramCount  Column #  TotalFindings  HU  PIR  \
# 877  WOLF CREEK  2014        7           0         2             12  11    5
# 878  WOLF CREEK  2015        8           2         1             10   9    0
# 879  WOLF CREEK  2016        5           0         1             11  11    9
# 880  WOLF CREEK  2017        2           0         2             12   8    4
# 881  WOLF CREEK  2018        4           0         2              7   8    5
#
#      SSFF
# 877     0
# 878     2
# 879     1
# 880     2
# 881     0

# %%
predictor = predictor.reset_index()

# %%
predictor = predictor.drop(["index"], axis = 1)
predictor.tail()
# Out:
#            Site  Year  ENCount  ScramCount  Column #  TotalFindings  HU  PIR  \
# 819  WOLF CREEK  2014        7           0         2             12  11    5
# 820  WOLF CREEK  2015        8           2         1             10   9    0
# 821  WOLF CREEK  2016        5           0         1             11  11    9
# 822  WOLF CREEK  2017        2           0         2             12   8    4
# 823  WOLF CREEK  2018        4           0         2              7   8    5
#
#      SSFF
# 819     0
# 820     2
# 821     1
# 822     2
# 823     0

# %%
#extra rows in predictor are final year of operation for plants that did not have a "next year" action matrix column
#eliminate predictor rows for CR, KEW, SONGS 2013, VY 2014, FCS 2016, OC 2018
predictor[predictor["Site"] == "VERMONT YANKEE"]
# Out:
#                Site  Year  ENCount  ScramCount  Column #  TotalFindings  HU  \
# 763  VERMONT YANKEE  2006        5           0         2              5   1
# 764  VERMONT YANKEE  2007        7           1         2              6   3
# 765  VERMONT YANKEE  2008        5           0         1             12   7
# 766  VERMONT YANKEE  2009        2           0         1              5   4
# 767  VERMONT YANKEE  2010        8           1         1              8   4
# 768  VERMONT YANKEE  2011        8           0         1              5   7
# 769  VERMONT YANKEE  2012        1           0         1              6   6
# 770  VERMONT YANKEE  2013        5           0         1             13  10
# 771  VERMONT YANKEE  2014        2           0         1              8   8
#
#      PIR  SSFF
# 763    2     0
# 764    2     1
# 765    2     0
# 766    2     0
# 767    2     0
# 768    1     2
# 769    1     1
# 770    3     2
# 771    1     1

# %%
predictor = predictor.drop([189,291,377,494,658,771])

# %%
predictor = predictor.reset_index()
predictor.tail()
# Out:
#      index        Site  Year  ENCount  ScramCount  Column #  TotalFindings  \
# 813    819  WOLF CREEK  2014        7           0         2             12
# 814    820  WOLF CREEK  2015        8           2         1             10
# 815    821  WOLF CREEK  2016        5           0         1             11
# 816    822  WOLF CREEK  2017        2           0         2             12
# 817    823  WOLF CREEK  2018        4           0         2              7
#
#      HU  PIR  SSFF
# 813  11    5     0
# 814   9    0     2
# 815  11    9     1
# 816   8    4     2
# 817   8    5     0

# %%
predictor = predictor.drop(["index"], axis = 1)
predictor.tail()
# Out:
#            Site  Year  ENCount  ScramCount  Column #  TotalFindings  HU  PIR  \
# 813  WOLF CREEK  2014        7           0         2             12  11    5
# 814  WOLF CREEK  2015        8           2         1             10   9    0
# 815  WOLF CREEK  2016        5           0         1             11  11    9
# 816  WOLF CREEK  2017        2           0         2             12   8    4
# 817  WOLF CREEK  2018        4           0         2              7   8    5
#
#      SSFF
# 813     0
# 814     2
# 815     1
# 816     2
# 817     0

# %%
AMNextYear = AMNextYear[["NextYearColumn"]]
AMNextYear.tail()
# Out:
#      NextYearColumn
# 813               1
# 814               1
# 815               2
# 816               2
# 817               1

# %%
predictor["NextYearColukm"]
